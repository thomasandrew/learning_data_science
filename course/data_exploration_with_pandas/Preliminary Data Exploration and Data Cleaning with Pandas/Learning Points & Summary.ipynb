# %%
import pandas as pd

df = pd.read_csv('salaries_by_college_major.csv')

clean_df = df.dropna()

clean_df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
# Use .head(), .tail(), .shape and .columns to explore your DataFrame and find out the number of rows and columns as well as the column names.

clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
clean_df.shape
# Out:
# (50, 6)

# %%
clean_df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
# Look for NaN (not a number) values with .findna() and consider using .dropna() to clean up your DataFrame.

clean_df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
# You can access entire columns of a DataFrame using the square bracket notation:
# df['column name'] or df[['column name 1', 'column name 2', 'column name 3']]

clean_df['Undergraduate Major']
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
clean_df[['Undergraduate Major', 'Starting Median Salary', 'Mid-Career Median Salary']]
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
# You can access individual cells in a DataFrame by chaining square brackets df['column name'][index] or using df['column name'].loc[index]

clean_df['Undergraduate Major'][5]
# Out:
# 'Art History'

# %%
clean_df.loc[3]
# Out:
# Undergraduate Major                  Anthropology
# Starting Median Salary                    36800.0
# Mid-Career Median Salary                  61500.0
# Mid-Career 10th Percentile Salary         33800.0
# Mid-Career 90th Percentile Salary        138000.0
# Group                                        HASS
# Name: 3, dtype: object

# %%
# The largest and smallest values, as well as their positions, can be found with methods like .max(), .min(), .idxmax() and .idxmin()

clean_df.max()
# Out:
# Undergraduate Major                   Spanish
# Starting Median Salary                74300.0
# Mid-Career Median Salary             107000.0
# Mid-Career 10th Percentile Salary     71900.0
# Mid-Career 90th Percentile Salary    210000.0
# Group                                    STEM
# dtype: object

# %%
clean_df.min()
# Out:
# Undergraduate Major                  Accounting
# Starting Median Salary                  34000.0
# Mid-Career Median Salary                52000.0
# Mid-Career 10th Percentile Salary       26700.0
# Mid-Career 90th Percentile Salary       96400.0
# Group                                  Business
# dtype: object

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Mid-Career 10th Percentile Salary'].idxmin()
# Out:
# 39

# %%
# You can sort the DataFrame with .sort_values() and add new columns with .insert()
# ps: Come back and learn this part again

nova = {'Col1':[1,2,3]}

clean_df.insert(1, 'mais', nova)

# %%
clean_df.head()
# Out:
#      Undergraduate Major mais  Starting Median Salary  \
# 0             Accounting  NaN                 46000.0
# 1  Aerospace Engineering  NaN                 57700.0
# 2            Agriculture  NaN                 42600.0
# 3           Anthropology  NaN                 36800.0
# 4           Architecture  NaN                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# 3                           138000.0      HASS
# ...

# %%
del clean_df["mais"] # To delete a column

# %%
clean_df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
clean_df.sort_values('Starting Median Salary')
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 49                               Spanish                 34000.0
# 47                              Religion                 34100.0
# 18                             Education                 34900.0
# 15                      Criminal Justice                 35000.0
# 34                            Journalism                 35600.0
# 26                        Graphic Design                 35700.0
# 5                            Art History                 35800.0
# 16                                 Drama                 35900.0
# 46                            Psychology                 35900.0
# 39                                 Music                 35900.0
# 32                       Interior Design                 36100.0
# 48                             Sociology                 36500.0
# 3                           Anthropology                 36800.0
# ...

# %%
# To create an Excel Style Pivot Table by grouping entries that belong to a particular category use the .groupby() method

clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Starting Median Salary  \
# Group
# Business                   12                      12
# HASS                       22                      22
# STEM                       16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16
