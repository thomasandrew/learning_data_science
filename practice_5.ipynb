# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.shape
# Out:
# (742, 13)

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  742.000000  742.00000  742.000000  742.000000  742.000000  742.000000
# mean   371.500000  422.71159   68.699461   75.803235   71.439353   70.113208
# std    214.341239  111.89932   25.979645   29.657225   29.467766   29.979536
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    186.250000  325.00000   50.000000   55.000000   50.000000   45.250000
# 50%    371.500000  430.00000   65.000000   75.000000   67.000000   65.000000
# 75%    556.750000  500.00000   80.000000   95.000000   89.750000   90.000000
# max    742.000000  720.00000  255.000000  180.000000  230.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count  742.000000  742.000000  742.000000
# mean    70.088949   66.567385    3.358491
# std     27.308952   27.899185    1.660302
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %%
df.Attack.max()
# Out:
# 180

# %%
df.Attack.idxmax()
# Out:
# 385

# %%
df.iloc()[385]
# Out:
# #                       386
# Name          Deoxys Attack
# Type 1              Psychic
# Type 2                  NaN
# Total                   600
# HP                       50
# Attack                  180
# Defense                  20
# Sp. Atk                 180
# Sp. Def                  20
# Speed                   150
# Generation                3
# Legendary              True
# Name: 385, dtype: object

# %%
df.isna()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False    True  False  False   False    False    False
# 4    False  False   False    True  False  False   False    False    False
# ..     ...    ...     ...     ...    ...    ...     ...      ...      ...
# 737  False  False   False   False  False  False   False    False    False
# 738  False  False   False   False  False  False   False    False    False
# 739  False  False   False   False  False  False   False    False    False
# 740  False  False   False   False  False  False   False    False    False
# 741  False  False   False   False  False  False   False    False    False
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.isna().values.any()
# Out:
# True

# %%
df.isna().values.any().sum()
# Out:
# 1

# %%
df.dropna(inplace=True)

# %%
df.isna().values.any()
# Out:
# False

# %%
df['Attack'].min()
# Out:
# 10

# %%
df['Attack'].idxmin()
# Out:
# 211

# %%
df.iloc()[211]
# Out:
# #                447
# Name           Gible
# Type 1        Dragon
# Type 2        Ground
# Total            300
# HP                58
# Attack            70
# Defense           45
# Sp. Atk           40
# Sp. Def           45
# Speed             42
# Generation         4
# Legendary      False
# Name: 446, dtype: object

# %%
df[df['Type 2'] == 'Poison']
# Out:
#        #        Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur  Grass  Poison    405   60      62       63       80
# 2      3    Venusaur  Grass  Poison    525   80      82       83      100
# 12    13      Weedle    Bug  Poison    195   40      35       30       20
# 13    14      Kakuna    Bug  Poison    205   45      25       50       25
# 14    15    Beedrill    Bug  Poison    395   65      90       40       45
# 42    43      Oddish  Grass  Poison    320   45      50       55       75
# 43    44       Gloom  Grass  Poison    395   60      65       70       85
# 44    45   Vileplume  Grass  Poison    490   75      80       85      110
# 47    48     Venonat    Bug  Poison    305   60      55       50       40
# 48    49    Venomoth    Bug  Poison    450   70      65       60       90
# 68    69  Bellsprout  Grass  Poison    300   50      75       35       70
# ...

# %%
df.head()
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 5    6   Charizard   Fire  Flying    534  78      84       78      109
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 5        85    100           1      False
# 11       80     70           1      False

# %%
df['Type 2'].head(50)
# Out:
# 0        Poison
# 1        Poison
# 2        Poison
# 5        Flying
# 11       Flying
# 12       Poison
# 13       Poison
# 14       Poison
# 15       Flying
# 16       Flying
# 17       Flying
# 20       Flying
# 21       Flying
# 30       Ground
# 33       Ground
# 38        Fairy
# 39        Fairy
# 40       Flying
# 41       Flying
# 42       Poison
# 43       Poison
# 44       Poison
# 45        Grass
# 46        Grass
# 47       Poison
# 48       Poison
# 61     Fighting
# 68       Poison
# 69       Poison
# 70       Poison
# 71       Poison
# 72       Poison
# 73       Ground
# 74       Ground
# 75       Ground
# 78      Psychic
# 79      Psychic
# 80        Steel
# 81        Steel
# 82       Flying
# 83       Flying
# 84       Flying
# 86          Ice
# 90          Ice
# 91       Poison
# 92       Poison
# 93       Poison
# 94       Ground
# 101     Psychic
# 102     Psychic
# Name: Type 2, dtype: object

# %%
df['Type 1'].head(50)
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 5          Fire
# 11          Bug
# 12          Bug
# 13          Bug
# 14          Bug
# 15       Normal
# 16       Normal
# 17       Normal
# 20       Normal
# 21       Normal
# 30       Poison
# 33       Poison
# 38       Normal
# 39       Normal
# 40       Poison
# 41       Poison
# 42        Grass
# 43        Grass
# 44        Grass
# 45          Bug
# 46          Bug
# 47          Bug
# 48          Bug
# 61        Water
# 68        Grass
# 69        Grass
# 70        Grass
# 71        Water
# 72        Water
# 73         Rock
# 74         Rock
# 75         Rock
# 78        Water
# 79        Water
# 80     Electric
# 81     Electric
# 82       Normal
# 83       Normal
# 84       Normal
# 86        Water
# 90        Water
# 91        Ghost
# 92        Ghost
# 93        Ghost
# 94         Rock
# 101       Grass
# 102       Grass
# Name: Type 1, dtype: object

# %%
df[(df['Type 2'] == 'Fighting') & (df['Type 1'] == 'Grass')]
# Out:
#        #        Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 284  285     Breloom  Grass  Fighting    460  60     130       80       60
# 651  652    Virizion  Grass  Fighting    580  91      90       72       90
# 670  671  Chesnaught  Grass  Fighting    530  88     107      122       74
#
#      Sp. Def  Speed  Generation  Legendary
# 284       60     70           3      False
# 651      129    108           5       True
# 670       75     64           6      False

# %%
plt.scatter(df.Total, df.Legendary)

# %%
sns.scatterplot(x='Total', y='Legendary', data=df)
# Out:
# <Axes: xlabel='Total', ylabel='Legendary'>

# %%
df[df['Legendary'] == 1]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 142  143             Articuno       Ice    Flying    580   90      85
# 143  144               Zapdos  Electric    Flying    580   90      90
# 144  145              Moltres      Fire    Flying    580   90     100
# 148  149               Mewtwo   Psychic       NaN    680  106     110
# 241  242               Raikou  Electric       NaN    580   90      85
# 242  243                Entei      Fire       NaN    580  115     115
# 243  244              Suicune     Water       NaN    580  100      75
# 247  248                Lugia   Psychic    Flying    680  106      90
# 248  249                Ho-oh      Fire    Flying    680  106     130
# 375  376             Regirock      Rock       NaN    580   80     100
# 376  377               Regice       Ice       NaN    580   80      50
# 377  378            Registeel     Steel       NaN    580   80      75
# ...

# %%
df[df['Legendary'] == 0].head(10)
# Out:
#     #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
# 5   6   Charizard   Fire  Flying    534  78      84       78      109
# 6   7    Squirtle  Water     NaN    314  44      48       65       50
# 7   8   Wartortle  Water     NaN    405  59      63       80       65
# 8   9   Blastoise  Water     NaN    530  79      83      100       85
# 9  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
df[df['Legendary'] == 1].value_counts("Type 1")
# Out:
# Type 1
# Psychic     12
# Dragon       9
# Fire         5
# Electric     4
# Steel        4
# Grass        3
# Ground       3
# Rock         3
# Water        3
# Dark         2
# Flying       2
# Ghost        2
# Ice          2
# Normal       2
# Fairy        1
# Name: count, dtype: int64

# %%
df.groupby('Type 1').count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        65    65      48     65   65      65       65       65       65
# Dark       28    28      19     28   28      28       28       28       28
# Dragon     26    26      15     26   26      26       26       26       26
# Electric   42    42      16     42   42      42       42       42       42
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   25    25       5     25   25      25       25       25       25
# Fire       48    48      20     48   48      48       48       48       48
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      24    24      15     24   24      24       24       24       24
# Grass      67    67      34     67   67      67       67       67       67
# Ground     31    31      18     31   31      31       31       31       31
# ...

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue='Legendary')

# %%
data = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
sns.heatmap(data, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.Legendary.count()
# Out:
# 742

# %%
df.Generation.describe()
# Out:
# count    742.000000
# mean       3.358491
# std        1.660302
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        6.000000
# Name: Generation, dtype: float64

# %%
df.Generation.dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df[df['Name'] == 'Mew']
# Out:
#        # Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 149  150  Mew  Psychic    NaN    600  100     100      100      100      100
#
#      Speed  Generation  Legendary
# 149    100           1      False

# %%
df[df['Name'] == 'Mewtwo']
# Out:
#        #    Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 148  149  Mewtwo  Psychic    NaN    680  106     110       90      154
#
#      Sp. Def  Speed  Generation  Legendary
# 148       90    130           1       True

# %%
df.loc[148]
# Out:
# #                 149
# Name           Mewtwo
# Type 1        Psychic
# Type 2            NaN
# Total             680
# HP                106
# Attack            110
# Defense            90
# Sp. Atk           154
# Sp. Def            90
# Speed             130
# Generation          1
# Legendary        True
# Name: 148, dtype: object

# %%
df[['Name', 'Legendary']]
# Out:
#                     Name  Legendary
# 0              Bulbasaur      False
# 1                Ivysaur      False
# 2               Venusaur      False
# 3             Charmander      False
# 4             Charmeleon      False
# ..                   ...        ...
# 737              Zygarde       True
# 738              Diancie       True
# 739  HoopaHoopa Confined       True
# 740   HoopaHoopa Unbound       True
# 741            Volcanion       True
#
# [742 rows x 2 columns]

# %%
df[(df['Generation'] == 1) & (df['Legendary'] == True)]
# Out:
#        #      Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 142  143  Articuno       Ice  Flying    580   90      85      100       95
# 143  144    Zapdos  Electric  Flying    580   90      90       85      125
# 144  145   Moltres      Fire  Flying    580   90     100       90      125
# 148  149    Mewtwo   Psychic     NaN    680  106     110       90      154
#
#      Sp. Def  Speed  Generation  Legendary
# 142      125     85           1       True
# 143       90    100           1       True
# 144       85     90           1       True
# 148       90    130           1       True

# %%
df[(df['Generation'] == 1) & (df['Legendary'] == False)]
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 141  142     Snorlax   Normal     NaN    540  160     110       65       65
# 145  146     Dratini   Dragon     NaN    300   41      64       45       50
# 146  147   Dragonair   Dragon     NaN    420   61      84       65       70
# 147  148   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['Generation'] == 1) & (df['Legendary'] == True)].count()
# Out:
# #             4
# Name          4
# Type 1        4
# Type 2        3
# Total         4
# HP            4
# Attack        4
# Defense       4
# Sp. Atk       4
# Sp. Def       4
# Speed         4
# Generation    4
# Legendary     4
# dtype: int64

# %%
df[(df['Generation'] == 1) & (df['Legendary'] == True)].describe()
# Out:
#                 #  Total     HP      Attack     Defense     Sp. Atk  \
# count    4.000000    4.0    4.0    4.000000    4.000000    4.000000
# mean   145.250000  605.0   94.0   96.250000   91.250000  124.750000
# std      2.629956   50.0    8.0   11.086779    6.291529   24.088379
# min    143.000000  580.0   90.0   85.000000   85.000000   95.000000
# 25%    143.750000  580.0   90.0   88.750000   88.750000  117.500000
# 50%    144.500000  580.0   90.0   95.000000   90.000000  125.000000
# 75%    146.000000  605.0   94.0  102.500000   92.500000  132.250000
# max    149.000000  680.0  106.0  110.000000  100.000000  154.000000
#
#           Sp. Def       Speed  Generation
# count    4.000000    4.000000         4.0
# mean    97.500000  101.250000         1.0
# std     18.484228   20.155644         0.0
# min     85.000000   85.000000         1.0
# 25%     88.750000   88.750000         1.0
# 50%     90.000000   95.000000         1.0
# 75%     98.750000  107.500000         1.0
# ...

# %%
df[df['Name'] == 'Pikachu']
# Out:
#      #     Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 24  25  Pikachu  Electric    NaN    320  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary
# 24       50     90           1      False

# %%
df['Type 2'].isna().any()
# Out:
# True

# %%
df.dropna(inplace=True)

# %%
df['Type 2'].isna().any()
# Out:
# False

# %%
df.head()
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 5    6   Charizard   Fire  Flying    534  78      84       78      109
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 5        85    100           1      False
# 11       80     70           1      False

# %%
df.shape
# Out:
# (368, 13)
