# %%
import pandas as pd

# %% [markdown]
# ## 1. Create

# %% [markdown]
# <p style="font-weight: bold;">1.1 Create a CSV</p>

# %%
df = pd.read_csv('telco_churn.csv')

# %% [markdown]
# <p style="font-weight: bold;">1.2 Create from a dictionary</p>

# %%
tempdict = {'col1':[1,2,3], 'col2':[4,5,6], 'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# ## 2. Read

# %% [markdown]
# <p style="font-weight: bold;">2.1 Show Top 5 and Top Bottom 5 Rows</p>

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
